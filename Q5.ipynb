# %%
fn=input("Enter your First Name: ");
ln=input("Enter your Last Name: ");
print("your Entered Name is: ",fn,"",ln,"The Reverse order is: ",ln,"",fn);
# Out:
# Enter your First Name: salman
# Enter your Last Name: saleem shaikh
# your Entered Name is:  salman  saleem shaikh The Reverse order is:  saleem shaikh  salman
