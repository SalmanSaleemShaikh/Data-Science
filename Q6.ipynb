# %%
n1=input("Enter First number: ");
n2=input("Enter Second number: ");
sum = float(n1)+float(n2);
print("The Addition of Two number is: ",sum);
# Out:
# Enter First number: 2
# Enter Second number: 5
# The Addition of Two number is:  7.0
